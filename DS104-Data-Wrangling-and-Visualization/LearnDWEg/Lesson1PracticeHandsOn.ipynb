# %% [markdown]
# # Importing the package

# %%
import pandas as pd

# %% [markdown]
# # Importing the FakeNews excel sheet

# %%
FakeNews = pd.read_excel('/Users/nehag/Documents/GitHub/DS-Student-Resources/DS104-Data-Wrangling-and-Visualization/LearnDWEg/FakeNews.xlsx')

# %%
FakeNews.head(10)
# Out:
#               when                                                url  \
# 0  before-nov-2016  http://wayback.archive.org/web/20161004072420i...
# 1  before-nov-2016  http://wayback.archive.org/web/20161004072420i...
# 2  before-nov-2016  http://wayback.archive.org/web/20161004072420i...
# 3  before-nov-2016  http://wayback.archive.org/web/20161004072420i...
# 4  before-nov-2016  http://wayback.archive.org/web/20161004072420i...
# 5  before-nov-2016  http://wayback.archive.org/web/20161004072420i...
# 6  before-nov-2016  http://wayback.archive.org/web/20161004072420i...
# 7  before-nov-2016  http://wayback.archive.org/web/20161001155200i...
# 8  before-nov-2016  http://wayback.archive.org/web/20161001155200i...
# 9  before-nov-2016  http://wayback.archive.org/web/20161001155200i...
#
#                           tracker StoryType
# 0                     DoubleClick      Fake
# 1                      RevContent      Fake
# 2                     DoubleClick      Fake
# ...

# %% [markdown]
# # Add a column labeled StoryType and fill it with Fake.

# %%
FakeNews['StoryType'] = 'Fake'

# %% [markdown]
# # Drop column 'when'

# %%
FakeNews.drop(['when'], axis = 1)
# Out:
#                                                     url  \
# 0     http://wayback.archive.org/web/20161004072420i...
# 1     http://wayback.archive.org/web/20161004072420i...
# 2     http://wayback.archive.org/web/20161004072420i...
# 3     http://wayback.archive.org/web/20161004072420i...
# 4     http://wayback.archive.org/web/20161004072420i...
# ...                                                 ...
# 3334  https://www.ncscooper.com/transgender-dog-unsu...
# 3335  https://www.ncscooper.com/transgender-dog-unsu...
# 3336  https://www.ncscooper.com/transgender-dog-unsu...
# 3337  https://www.ncscooper.com/transgender-dog-unsu...
# 3338  https://www.ncscooper.com/transgender-dog-unsu...
#
#                              tracker StoryType
# 0                        DoubleClick      Fake
# 1                         RevContent      Fake
# 2                        DoubleClick      Fake
# 3                 Google Syndication      Fake
# 4     DoubleClick Ad Exchange-Seller      Fake
# ...

# %% [markdown]
# # Separate the url column out so that you can see in one column the website and in the second column the domain.

# %%
FakeNews_Split = FakeNews['url'].str.split('_', expand =True).rename(columns = lambda x: 'Col' + str(x+1))

# %%
# Add the split dataset back in FakeNews dataset using concat function

FakeNews_C = pd.concat([FakeNews , FakeNews_Split], axis = 1)

# %%
FakeNews_C.head(10)
# Out:
#               when                                                url  \
# 0  before-nov-2016  http://wayback.archive.org/web/20161004072420i...
# 1  before-nov-2016  http://wayback.archive.org/web/20161004072420i...
# 2  before-nov-2016  http://wayback.archive.org/web/20161004072420i...
# 3  before-nov-2016  http://wayback.archive.org/web/20161004072420i...
# 4  before-nov-2016  http://wayback.archive.org/web/20161004072420i...
# 5  before-nov-2016  http://wayback.archive.org/web/20161004072420i...
# 6  before-nov-2016  http://wayback.archive.org/web/20161004072420i...
# 7  before-nov-2016  http://wayback.archive.org/web/20161001155200i...
# 8  before-nov-2016  http://wayback.archive.org/web/20161001155200i...
# 9  before-nov-2016  http://wayback.archive.org/web/20161001155200i...
#
#                           tracker StoryType  \
# 0                     DoubleClick      Fake
# 1                      RevContent      Fake
# 2                     DoubleClick      Fake
# ...

# %% [markdown]
# # Unite the Domain back

# %%
FakeNews_C['urlnew'] = FakeNews_C['Col1'] + '_' + FakeNews_C['Col2'].map(str)

FakeNews_C.drop(['url'], axis = 1)
# Out:
#                      when                         tracker StoryType  \
# 0         before-nov-2016                     DoubleClick      Fake
# 1         before-nov-2016                      RevContent      Fake
# 2         before-nov-2016                     DoubleClick      Fake
# 3         before-nov-2016              Google Syndication      Fake
# 4         before-nov-2016  DoubleClick Ad Exchange-Seller      Fake
# ...                   ...                             ...       ...
# 3334  2017-03-01 00:00:00                     DoubleClick      Fake
# 3335  2017-03-01 00:00:00              Google Syndication      Fake
# 3336  2017-03-01 00:00:00  DoubleClick Ad Exchange-Seller      Fake
# 3337  2017-03-01 00:00:00                         AddThis      Fake
# 3338  2017-03-01 00:00:00                  Google Adsense      Fake
#
#                                                    Col1  \
# 0       http://wayback.archive.org/web/20161004072420id
# ...

# %%
FakeNews_C.head()
# Out:
#               when                                                url  \
# 0  before-nov-2016  http://wayback.archive.org/web/20161004072420i...
# 1  before-nov-2016  http://wayback.archive.org/web/20161004072420i...
# 2  before-nov-2016  http://wayback.archive.org/web/20161004072420i...
# 3  before-nov-2016  http://wayback.archive.org/web/20161004072420i...
# 4  before-nov-2016  http://wayback.archive.org/web/20161004072420i...
#
#                           tracker StoryType  \
# 0                     DoubleClick      Fake
# 1                      RevContent      Fake
# 2                     DoubleClick      Fake
# 3              Google Syndication      Fake
# 4  DoubleClick Ad Exchange-Seller      Fake
#
#                                               Col1                     Col2  \
# 0  http://wayback.archive.org/web/20161004072420id  /http://alertchild.com/
# 1  http://wayback.archive.org/web/20161004072420id  /http://alertchild.com/
# ...

# %% [markdown]
# # Keep only the first ten rows of the data

# %%
FakeNews10 = FakeNews[:10]
FakeNews10
# Out:
#               when                                                url  \
# 0  before-nov-2016  http://wayback.archive.org/web/20161004072420i...
# 1  before-nov-2016  http://wayback.archive.org/web/20161004072420i...
# 2  before-nov-2016  http://wayback.archive.org/web/20161004072420i...
# 3  before-nov-2016  http://wayback.archive.org/web/20161004072420i...
# 4  before-nov-2016  http://wayback.archive.org/web/20161004072420i...
# 5  before-nov-2016  http://wayback.archive.org/web/20161004072420i...
# 6  before-nov-2016  http://wayback.archive.org/web/20161004072420i...
# 7  before-nov-2016  http://wayback.archive.org/web/20161001155200i...
# 8  before-nov-2016  http://wayback.archive.org/web/20161001155200i...
# 9  before-nov-2016  http://wayback.archive.org/web/20161001155200i...
#
#                           tracker StoryType
# 0                     DoubleClick      Fake
# 1                      RevContent      Fake
# 2                     DoubleClick      Fake
# ...

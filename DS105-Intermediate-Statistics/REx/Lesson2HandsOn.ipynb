# %% [markdown]
# # Transforming Data in Python

# %% [markdown]
# ## Import Packages

# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %% [markdown]
# ## Load data

# %%
Seattle_ParksnRec = pd.read_csv("Seattle_ParksnRec.csv")

# %%
## Assess the skew of the distribution and then transform it if necessary for the following variables:

# of trips Winter
# of participants Winter
# of trips Spring
# of participants Spring
# of trips Summer
# of participants Summer

# %%
# List of Columns names

list(Seattle_ParksnRec.columns)
# Out:
# ['Geographic Region',
#  'Year',
#  '# of trips Winter',
#  '# of participants Winter',
#  '# of trips Spring',
#  '# of participants Spring',
#  '# of trips Summer',
#  '# of participants Summer',
#  '# of trips Fall',
#  '# of participants Fall',
#  '# of trips per year',
#  '# participants per year',
#  'increase/decrease of prior year',
#  'Average # people per trip']

# %% [markdown]
# # 1. '# of trips Winter'

# %% [markdown]
# ### Visualize the distribution and transformation

# %%
sns.displot(data = Seattle_ParksnRec, x = '# of trips Winter', kde = True)

# %%
# It looks slightly positively skewed, so we need to perform sqrt

Seattle_ParksnRec['# of trips Winter_SQRT'] = np.sqrt(Seattle_ParksnRec['# of trips Winter'])

# %%
# Graphing again 

sns.displot(data = Seattle_ParksnRec, x = '# of trips Winter_SQRT', kde = True)

# %%
## It looks a little better.

# Seattle_ParksnRec['# of trips Winter_log'] = np.log(Seattle_ParksnRec['# of trips Winter'])

# Seattle_ParksnRec.dropna(inplace = True)

# sns.displot(data = Seattle_ParksnRec, x = '# of trips Winter_log', kde = True)

# %% [markdown]
# ## 2. '# of participants Winter'

# %%
sns.displot(data = Seattle_ParksnRec, x = '# of participants Winter', kde = True)

# %%
# This looks slightly positively skewed, so we need to calculate sqrt

Seattle_ParksnRec['# of participants Winter_SQRT'] = np.sqrt(Seattle_ParksnRec['# of participants Winter'])

# %%
# Graphing 

sns.displot(data = Seattle_ParksnRec, x = '# of participants Winter_SQRT', kde = True)

# %%
# It looks much better.

# %% [markdown]
# # 3. '# of trips Spring'

# %%
sns.displot(data = Seattle_ParksnRec, x = '# of trips Spring', kde = True)

# %%
# this looks positively Skewed, so calculating sqrt

Seattle_ParksnRec['# of trips Spring_SQRT'] = np.sqrt(Seattle_ParksnRec['# of trips Spring'])

# %%
# Graphing

sns.displot(data = Seattle_ParksnRec, x = '# of trips Spring_SQRT', kde = True)

# %%
# This looks better

# %% [markdown]
# # 4. '# of participants Spring'

# %%
# sns.distplot(Seattle_ParksnRec['# of participants Spring'])

sns.displot(data = Seattle_ParksnRec, x = '# of participants Spring', kde = True)

# %%
# this looks positively Skewed, so calculating sqrt

Seattle_ParksnRec['# of participants Spring_SQRT'] = np.sqrt(Seattle_ParksnRec['# of participants Spring'])

# %%
# Graphing

sns.displot(data = Seattle_ParksnRec, x = '# of participants Spring_SQRT', kde = True)

# %%
# It's slightly better but not much difference.

# %% [markdown]
# # 5. '# of trips Summer'

# %%
sns.displot(data = Seattle_ParksnRec, x = '# of trips Summer', kde = True)

# %%
# This looks slightly positively skewed but al ot normally distributed.

# %%
Seattle_ParksnRec['# of trips Summer_SQRT'] = np.sqrt(Seattle_ParksnRec['# of trips Summer'])

# %%
# Graphing
 
sns.displot(data = Seattle_ParksnRec, x = '# of trips Summer_SQRT', kde = True)

# %%
# It looks better now.

# %% [markdown]
# # 6. '# of participants Summer'

# %%
sns.displot(data = Seattle_ParksnRec, x = '# of participants Summer', kde = True)

# %%
# this looks slight positively Skewed, so calculating sqrt

Seattle_ParksnRec['# of participants Summer_SQRT'] = np.sqrt(Seattle_ParksnRec['# of participants Summer'])

# %%
sns.displot(data = Seattle_ParksnRec, x = '# of participants Summer_SQRT', kde = True)

# %%
# Better looking.

# %% [markdown]
# ## WE can say that all the given variables are positively skewed and using the sqrt function, helped them transform into normal distribution.

# %% [markdown]
# ## Variable '# of trips Summer' is closest to normal distribution.
